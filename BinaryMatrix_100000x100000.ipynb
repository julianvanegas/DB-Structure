# %%
# Montar en Google Drive
#from google.colab import drive
#drive.mount('/content/drive')
#file_path = "/content/drive/MyDrive/matrix.txt"

# Montar en disco
file_path = "matrix.txt"

with open(file_path, 'wb') as f:
  for i in range(100000):
    # Escribir 100,000 bytes de valor 1
    f.write(bit([1]) * 100000)
    # Escribir 100,000 bytes de valor 0
    f.write(bytes([0]) * 100000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-6058/747028172.py in <cell line: 0>()
#      10   for i in range(100000):
#      11     # Escribir 100,000 caracteres '1'
# ---> 12     f.write('1' * 100000)
#      13     # Escribir 100,000 caracteres '0'
#      14     f.write('0' * 100000)
#
# KeyboardInterrupt:

# %%
import os
print(os.path.getsize(file_path) / (1024**3))
# Out:
# 18.62645149230957
